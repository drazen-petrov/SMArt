# %% [markdown]
# # porting GROMOS topologies to openMM

# %% [markdown]
# ## importing `openMM_Factory`

# %%
import os
import numpy as np

import sys
SMArt_fd = os.path.abspath(os.getcwd())
for _ in range(2):
    SMArt_fd = os.path.split(SMArt_fd)[0]
sys.path.insert(0, SMArt_fd)
# if SMArt in the path, this can be removed 

import SMArt
from SMArt.md.openMM_Factory import openMM_Factory
from SMArt.md import parse_top, parse_cnf, parse_imd
from SMArt.md.data_st import Trajectory

# %%
from openmm import NoseHooverIntegrator, LangevinIntegrator
from openmm.app import Simulation
from openmm.app.internal.unitcell import reducePeriodicBoxVectors
from openmm.app.pdbfile import PDBFile
from openmm.unit import kelvin, picosecond, picoseconds

# %% [markdown]
# ## parse GROMOS files

# %%
data_fd = os.path.abspath(os.path.join(os.path.split(SMArt.__file__)[0], '..', 'doc', 'some_data'))
data_fd = os.path.join(data_fd, 'gromos', 'GLY_LYSH_KMC')

cnf_file = os.path.join(data_fd, 'gath_gbond_eq_GLY_LYSH_KMC.cnf')
cnf = parse_cnf(cnf_file)
# IMPORTANT - the cnf has to be gathered! see tests at the bottom
top_file = os.path.join(data_fd, 'GLY_LYSH_KMC.top')
top = parse_top(top_file)
imd_file = os.path.join(data_fd, 'md.imd')
imd = parse_imd(imd_file)

# %% [markdown]
# ## generate openMM Simulation object

# %%
openMM_sys = openMM_Factory(top=top, MD_params=imd) # initialize
integrator = NoseHooverIntegrator(300*kelvin, 0.1/picosecond, 0.002*picoseconds)
simulation = openMM_sys.create_openMM_simulation(cnf, integrator)
# Out:
# setting eps1 = 1.

# %% [markdown]
# ## use the `simulation` object
#
# e.g. calculate energies

# %%
for FG_name, i in openMM_sys.FG_map.items():
    st = simulation.context.getState(getPositions=True, getEnergy=True, groups={i})
    print('{:<35} {:<5}'.format(FG_name, i), st.getPotentialEnergy())

print('\ntotal')
st = simulation.context.getState(getPositions=True, getEnergy=True, getForces=True)
print(st.getPotentialEnergy())
# Out:
# FG_BONDS                            0     0.0 kJ/mol
# FG_ANGLES                           1     90.9322509765625 kJ/mol
# FG_IMPROPERS                        2     15.284769058227539 kJ/mol
# FG_DIHEDRALS                        3     42.674110412597656 kJ/mol
# FG_NB_NATIVE_GROUP                  4     0.0 kJ/mol
# FG_NB_LJ_coul_RF_RFC_CUSTOM         5     -84435.9375 kJ/mol
# FG_NB_LJ_CUSTOM_excl_14             6     -8.9487886428833 kJ/mol
# FG_NB_coul_RF_RFC_CUSTOM_14         7     406.5617370605469 kJ/mol
# FG_NB_RF_RFC_CUSTOM_excl            8     150757.171875 kJ/mol
# FG_NB_RFC_CUSTOM_self               9     -151014.40625 kJ/mol
#
# total
# -84146.640625 kJ/mol

# %% [markdown]
# ## checking energies with GROMOS
# works only if GROMOS installed

# %%
from SMArt.md.wrappers import run_gr_prog

# %%
# get the command to run md (1 step simulation)
sys_name = 'md_1step'
md_params = dict(topo=top_file, conf=cnf_file, input=imd_file, 
                 fin=sys_name+'.cnf', trc=sys_name+'.trc', tre=sys_name+'.tre',
                 trv=sys_name+'.trv', trf=sys_name+'.trf')
command = run_gr_prog('md', **md_params, pipe = (sys_name+'.omd', None))
# execute
os.system(command)
# get the energy
with open(sys_name+'.omd') as f:
    E_tot = None
    flag_MD_OK = False
    for l in f:
        if E_tot is None and "E_Potential" in l:
            E_tot = l.split()[-1]
        if 'finished successfully' in l:
            flag_MD_OK = True

trf = Trajectory("md_1step.trf") # read forces
# remove additional files created with simulations
os.system('rm {:}*'.format(sys_name))

assert flag_MD_OK
print(float(E_tot))
# Out:
# -84154.0

# %% [markdown]
# ### checking energies v2
# when native openMM charges and LJ parameters used

# %%
openMM_sys = openMM_Factory(top=top, MD_params=imd) # initialize
integrator = NoseHooverIntegrator(300*kelvin, 0.1/picosecond, 0.002*picoseconds)
simulation = openMM_sys.create_openMM_simulation(cnf, integrator, flag_openMM_native_charges=True)

st = simulation.context.getState(getPositions=True, getEnergy=True, getForces=True)
print(st.getPotentialEnergy())
# Out:
# setting eps1 = 1.
# -84146.6875 kJ/mol

# %% [markdown]
# ### checking forces (compare openMM with GROMOS)

# %%
st = simulation.context.getState(getPositions=True, getEnergy=True, getForces=True)
Fs = st.getForces(asNumpy=True) # get forces
# compare to GROMOS forces
dF = Fs._value - trf.coord
print(dF.min(), dF.max())
# Out:
# -39.61240963637829 41.124326050281525

# %%
from matplotlib import pyplot as plt
plt.hist(dF)
plt.xlabel('force [kJ/mol/nm]')
_=plt.legend(list('xyz'))

# %% [markdown]
# ## generate openMM Simulation object (from scratch)
# allows for more flexibility, e.g. pdb file can be used instead of a cnf

# %% [markdown]
# ### generate openMM_Factory instance

# %%
openMM_sys = openMM_Factory(top=top) # initialize without MD_params - some values set to defaults
#openMM_sys = openMM_Factory(top=top, MD_params=imd) # initialize with imd params
#openMM_sys = openMM_Factory(top=top, MD_params=dict(R_cutoff=1.4, RF_eps=78)) # initialize with dict params
# Out:
# setting R_cutoff = 1.4
# setting RF_eps = 62.
# setting eps1 = 1.
# setting kappa = 0
# setting flag_RF_excl = True

# %%
## use solute only or add water molecules
flag_water = True
if flag_water:
    # calculate number of water molecules
    N_water = int((len(cnf.atoms) - len(top.atoms)) / 3)
else:
    N_water=0

## use native openMM electrostatic calculation or custom made one
flag_openMM_native_charges = False
if not flag_openMM_native_charges:
    # GROMOS custom energy
    openMM_sys.make_predefined_openmm_system(native_charges=False, N_water=N_water)
else:
    # native openMM charges + custom GROMOM energy for the rest
    openMM_sys.make_predefined_openmm_system(native_charges=True, N_water=N_water)
# both options give the same result - there might be a difference in performance...
# option native_charges=True could be used in combination with PME (not implemented yet)

# %%
# cells above generate openMM system object
# stored in `system` attribute of the `openMM_Factory` instance
mm_sys = openMM_sys.system

# %% [markdown]
# ### generate openMM Simulation object

# %%
# generate openMM topology object (it could be made from a pdb file as well)
mm_top = openMM_sys.make_openmm_top()
# add the box information
mm_sys.setDefaultPeriodicBoxVectors(*reducePeriodicBoxVectors(np.diag(cnf.box.abc)))
mm_top.setPeriodicBoxVectors(reducePeriodicBoxVectors(np.diag(cnf.box.abc)))

# create integrator and simulation objects
integrator = NoseHooverIntegrator(300*kelvin, 0.1/picosecond, 0.002*picoseconds)
simulation = Simulation(mm_top, mm_sys, integrator)

# add coordinates and the box information to the simulation object
simulation.context.setPositions(cnf._coord)
simulation.context.setVelocities(cnf.get_velocities())
simulation.context.setPeriodicBoxVectors(*reducePeriodicBoxVectors(np.diag(cnf.box.abc)))

# %% [markdown]
# ### example with pdb file
# **NOTE:** the order of atoms in the pdb file has to match the order in the gromos topology!

# %%
openMM_sys = openMM_Factory(top=top, MD_params=imd) # initialize
# read pdb file
pdb_file = os.path.join(data_fd, 'gath_gbond_eq_GLY_LYSH_KMC.pdb')
pdb = PDBFile(pdb_file)
N_water = (len(pdb.positions) - len(top.atoms)) // 3

# generate system with GROMOS custom energy terms
openMM_sys.make_predefined_openmm_system(native_charges=False, N_water=N_water)
mm_sys = openMM_sys.system 

# add box information from the pdb file
mm_sys.setDefaultPeriodicBoxVectors(*pdb.topology.getPeriodicBoxVectors())

# create integrator and simulation objects
integrator = NoseHooverIntegrator(300*kelvin, 0.1/picosecond, 0.002*picoseconds)
simulation = Simulation(pdb.topology, mm_sys, integrator)

# add coordinates and the box information to the simulation object
simulation.context.setPositions(pdb.positions)
simulation.context.setPeriodicBoxVectors(*pdb.topology.getPeriodicBoxVectors())
# Out:
# setting eps1 = 1.
